# %%
# %load_ext autoreload helps when you edit .py files in VSCode
# It automatically updates the notebook without restarting the kernel.
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from src.config import SLAMConfig
from src.simulation import FireScoutSimulation

# Set plotting style for the notebook
plt.style.use('seaborn-v0_8-darkgrid')

# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from src.config import SLAMConfig              
from src.simulation import FireScoutSimulation

plt.style.use('seaborn-v0_8-darkgrid')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 get_ipython().run_line_magic('autoreload', '2')
#       4 import matplotlib.pyplot as plt
# ----> 5 from src.config import SLAMConfig
#       6 from src.simulation import FireScoutSimulation
#       8 plt.style.use('seaborn-v0_8-darkgrid')
#
# ModuleNotFoundError: No module named 'src'

# %%
config = SLAMConfig(
    num_steps=800, 
    num_hazards=10, 
    num_hotspots=3
)
sim = FireScoutSimulation(config)
sim.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 config = SLAMConfig(
#       2     num_steps=800,
#       3     num_hazards=10,
#       4     num_hotspots=3
#       5 )
#       6 sim = FireScoutSimulation(config)
#       7 sim.run()
#
# NameError: name 'SLAMConfig' is not defined
